# %% [markdown]
# # Data Viz Playground
# Started 3/8/2022
#
# For trying out different graphs and visualizations.
#
# Below are the imports for getting the data and putting it in a usable format. If you want to see the breakdown of this, check `ml_playground.ipynb`.

# %%
import json
import pandas as pd
import urllib.request as rq

COVID_WHOLE_DATA_URL = "https://covid.ourworldindata.org/data/owid-covid-data.json"

with rq.urlopen(COVID_WHOLE_DATA_URL) as url:
    covid_data = json.loads(url.read().decode())
    covid_df = pd.DataFrame(covid_data)

usa_df = covid_df['USA'].copy()
full_df = pd.DataFrame.from_dict(usa_df.data)

full_df.head()
# Out:
#          date  total_cases  total_cases_per_million  stringency_index  \
# 0  2020-01-22          1.0                    0.003               0.0
# 1  2020-01-23          1.0                    0.003               0.0
# 2  2020-01-24          2.0                    0.006               0.0
# 3  2020-01-25          2.0                    0.006               0.0
# 4  2020-01-26          5.0                    0.015               0.0
#
#    new_cases  new_cases_per_million  excess_mortality_cumulative_absolute  \
# 0        NaN                    NaN                                   NaN
# 1        0.0                  0.000                                   NaN
# 2        1.0                  0.003                                   NaN
# 3        0.0                  0.000                                   NaN
# 4        3.0                  0.009                               -8926.0
#
#    excess_mortality_cumulative  excess_mortality  \
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                        -3.59             -2.63
#
#    excess_mortality_cumulative_per_million  ...  \
# 0                                      NaN  ...
# 1                                      NaN  ...
# 2                                      NaN  ...
# 3                                      NaN  ...
# 4                               -26.811643  ...
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  new_vaccinations  \
# 0                                  NaN               NaN
# 1                                  NaN               NaN
# 2                                  NaN               NaN
# 3                                  NaN               NaN
# 4                                  NaN               NaN
#
#    new_vaccinations_smoothed  new_vaccinations_smoothed_per_million  \
# 0                        NaN                                    NaN
# 1                        NaN                                    NaN
# 2                        NaN                                    NaN
# 3                        NaN                                    NaN
# 4                        NaN                                    NaN
#
#    new_people_vaccinated_smoothed  new_people_vaccinated_smoothed_per_hundred  \
# 0                             NaN                                         NaN
# 1                             NaN                                         NaN
# 2                             NaN                                         NaN
# 3                             NaN                                         NaN
# 4                             NaN                                         NaN
#
#    total_boosters  total_boosters_per_hundred
# 0             NaN                         NaN
# 1             NaN                         NaN
# 2             NaN                         NaN
# 3             NaN                         NaN
# 4             NaN                         NaN
#
# [5 rows x 47 columns]

# %%
# For refreshing the DF after mistakes
data = full_df.copy()

# %%
import seaborn as sns

sns.lineplot(data=data["new_cases"].tail(90))
# Out:
# <AxesSubplot:ylabel='new_cases'>

# %% [markdown]
# ## We got the chart!
# Now we'll begin formatting it to look more presentable.
#
# What makes it look more presentable? A legend, title, labelling our axes, and generally being able to understand it. For instance, the y-axis is already labeled but since it's to the power of 6 it can be hard to understand by just looking at it.
#
# Also notice that the x-axis is using the default index from the dataframe. We'll be changing that to date.

# %%
data["date"] = pd.to_datetime(data["date"]) # Yes, it is necessary.
data.set_index("date", inplace=True)
data.head()
# Out:
#             total_cases  total_cases_per_million  stringency_index  new_cases  \
# date
# 2020-01-22          1.0                    0.003               0.0        NaN
# 2020-01-23          1.0                    0.003               0.0        0.0
# 2020-01-24          2.0                    0.006               0.0        1.0
# 2020-01-25          2.0                    0.006               0.0        0.0
# 2020-01-26          5.0                    0.015               0.0        3.0
#
#             new_cases_per_million  excess_mortality_cumulative_absolute  \
# date
# 2020-01-22                    NaN                                   NaN
# 2020-01-23                  0.000                                   NaN
# 2020-01-24                  0.003                                   NaN
# 2020-01-25                  0.000                                   NaN
# 2020-01-26                  0.009                               -8926.0
#
#             excess_mortality_cumulative  excess_mortality  \
# date
# 2020-01-22                          NaN               NaN
# 2020-01-23                          NaN               NaN
# 2020-01-24                          NaN               NaN
# 2020-01-25                          NaN               NaN
# 2020-01-26                        -3.59             -2.63
#
#             excess_mortality_cumulative_per_million  new_cases_smoothed  ...  \
# date                                                                     ...
# 2020-01-22                                      NaN                 NaN  ...
# 2020-01-23                                      NaN                 NaN  ...
# 2020-01-24                                      NaN                 NaN  ...
# 2020-01-25                                      NaN                 NaN  ...
# 2020-01-26                               -26.811643                 NaN  ...
#
#             total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# date
# 2020-01-22                             NaN                            NaN
# 2020-01-23                             NaN                            NaN
# 2020-01-24                             NaN                            NaN
# 2020-01-25                             NaN                            NaN
# 2020-01-26                             NaN                            NaN
#
#             people_fully_vaccinated_per_hundred  new_vaccinations  \
# date
# 2020-01-22                                  NaN               NaN
# 2020-01-23                                  NaN               NaN
# 2020-01-24                                  NaN               NaN
# 2020-01-25                                  NaN               NaN
# 2020-01-26                                  NaN               NaN
#
#             new_vaccinations_smoothed  new_vaccinations_smoothed_per_million  \
# date
# 2020-01-22                        NaN                                    NaN
# 2020-01-23                        NaN                                    NaN
# 2020-01-24                        NaN                                    NaN
# 2020-01-25                        NaN                                    NaN
# 2020-01-26                        NaN                                    NaN
#
#             new_people_vaccinated_smoothed  \
# date
# 2020-01-22                             NaN
# 2020-01-23                             NaN
# 2020-01-24                             NaN
# 2020-01-25                             NaN
# 2020-01-26                             NaN
#
#             new_people_vaccinated_smoothed_per_hundred  total_boosters  \
# date
# 2020-01-22                                         NaN             NaN
# 2020-01-23                                         NaN             NaN
# 2020-01-24                                         NaN             NaN
# 2020-01-25                                         NaN             NaN
# 2020-01-26                                         NaN             NaN
#
#            total_boosters_per_hundred
# date
# 2020-01-22                        NaN
# 2020-01-23                        NaN
# 2020-01-24                        NaN
# 2020-01-25                        NaN
# 2020-01-26                        NaN
#
# [5 rows x 46 columns]

# %%
# Now we have dates in the x-axis
sns.lineplot(data=data["new_cases"].tail(90))
# Out:
# <AxesSubplot:xlabel='date', ylabel='new_cases'>

# %%
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Increase the size of the plot
plt.figure(figsize=(14,6))

# Label the axes and give it a title
plt.title("New Cases over the last 90 days")
plt.xlabel("Date")
plt.ylabel("New Cases")

# Now to tackle the 1e6 x-axis
plt.ticklabel_format(style="plain", axis="y")

sns.lineplot(data=data["new_cases_smoothed_per_million"].tail(90))
# Out:
# <AxesSubplot:title={'center':'New Cases over the last 90 days'}, xlabel='Date', ylabel='New Cases'>

# %% [markdown]
# ## Now let's add multiple lines!

# %%
DAYS = 90

# Increase the size of the plot
plt.figure(figsize=(14,6))

# Label the axes and give it a title
plt.title(f"New Cases & Vaccinations Smoothed in the US over the last {DAYS} days")
plt.xlabel("Date")
plt.ylabel("New cases/Vaccinations per 1M People")

# Now to tackle the 1e6 x-axis
plt.ticklabel_format(style="plain", axis="y")

sns.lineplot(data=data["new_cases_smoothed_per_million"].tail(DAYS), label="New Cases")
sns.lineplot(data=data["new_vaccinations_smoothed_per_million"].tail(DAYS), label="New Vaccinations")
# Out:
# <AxesSubplot:title={'center':'New Cases & Vaccinations Smoothed in the US over the last 90 days'}, xlabel='Date', ylabel='New cases/Vaccinations per 1M People'>

# %%
new_cases_90 = data.loc[:,"new_cases_smoothed_per_million"].tail(90)

# %%
sns.kdeplot(data=data["new_cases_smoothed_per_million"])
plt.show()
# Out:
# <AxesSubplot:xlabel='new_cases_smoothed_per_million', ylabel='Density'>

# %%
data.loc[:,["new_cases"]].tail(120).plot()
plt.show()

# %%
data.loc[:,"new_cases"].tail(120).rolling(window=7, center=True).mean().plot()
plt.show()

# %%
sns.kdeplot(data=new_cases_90)
plt.axvline(new_cases_90.mean(), linewidth=2, color='green')
plt.axvline(new_cases_90.median(), linewidth=2, color='red')
plt.show()

# %%
new_cases_90.describe()
# Out:
# count      90.000000
# mean      361.710344
# std       464.845424
# min        80.126000
# 25%        94.842000
# 50%       123.190500
# 75%       373.192500
# max      1958.817000
# Name: new_cases_smoothed_per_million, dtype: float64
